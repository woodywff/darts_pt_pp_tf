# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import numpy as np
np.zeros?

# %%
from darts_tf.search import Searching
s = Searching()
# import numpy as np
# np.random.rand(1,28,28,1).astype('float32')

# %%
import tensorflow as tf
checkpoint = tf.train.Checkpoint(model=s.model)
# manager = tf.train.CheckpointManager(checkpoint=checkpoint,
#                                          directory='test_check/',checkpoint_name='last',
#                                          max_to_keep=1)
# manager.save()
checkpoint.restore('test_check/last-2')

# %%
import numpy as np
def accuracy(outputs, labels, topk=(1,)):
    """caculate accuracy"""
#     pdb.set_trace()
    maxk = max(topk)
    batch_size = labels.shape[0]

    pred = np.argsort(outputs)[:, ::-1][:, :maxk]
    correct = pred == np.reshape(labels, (batch_size, 1))

    results = []
    for k in topk:
        correct_k = np.sum(correct[:, :k])
        results.append(correct_k / batch_size)

    return results
output = np.random.rand(2,3)
labels = np.random.randint(0,3,size=(2,))
print(accuracy(output, labels, topk=(1,2,5)))
from darts_pt.utils import accuracy as ac
import torch
ac(torch.as_tensor(output), torch.as_tensor(labels), topk=(1,2))

# %%
labels.T

# %%
import tensorflow as tf
# from tensorflow.keras import Sequential, Input
from tensorflow.keras.layers import Dense, Flatten
input_shape = (2, 4, 5, 3)
x = tf.random.normal(input_shape)
y = tf.keras.layers.GlobalAveragePooling2D()(x)

print(y.shape)
print(Dense(10)(y).shape)
import torch.nn as nn
import torch
import numpy as np
pt_loss = nn.CrossEntropyLoss()
y_pred = np.random.rand(2,10)
y_truth = np.random.randint(0,10,size=(2,))
print(y_pred, y_truth)
y_pred_pt = torch.as_tensor(y_pred, dtype=torch.float)
y_truth_pt = torch.as_tensor(y_truth, dtype=torch.long)
print('pt loss:', pt_loss(y_pred_pt,y_truth_pt))

tf_loss = tf.keras.losses.SparseCategoricalCrossentropy()
print('tf loss:', tf_loss(tf.convert_to_tensor(y_truth), tf.convert_to_tensor(y_pred)))

def self_CrossEntropyLoss():
    """"cross entropy loss"""
    def cross_entropy_loss(y_true, y_pred):
        y_true = tf.cast(tf.reshape(y_true, [-1]), tf.int32)
        ce = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y_true,
                                                            logits=y_pred)

        return tf.reduce_mean(ce)
    return cross_entropy_loss

tf_loss2 = self_CrossEntropyLoss()
tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(tf.convert_to_tensor(y_truth), tf.convert_to_tensor(y_pred)))

# %%
import tensorflow as tf
print(tf.__version__)
print(tf.test.is_gpu_available())
from tensorflow.keras.layers import (Conv2D, SeparableConv2D, MaxPool2D, 
                                     AveragePooling2D, ReLU, BatchNormalization)

input_shape = (4, 14, 14, 1)
x = tf.random.normal(input_shape)
# from genotype import PRIMITIVES
# from darts_tf.ops import OPS
# for i in PRIMITIVES:
#     y = OPS[i](16,2,True)(x)
#     if y.shape[1] == 7:
#         y = tf.keras.layers.ZeroPadding2D(1)(y)
#     print(y.shape)

# %%
import pdb
import numpy as np

def test(p):
    return tf.keras.layers.Dropout(p)

class A(tf.keras.layers.Layer):
    def __init__(self, p=0.99):
        super().__init__()
        self.m = test(p)
    def call(self, x):
#         pdb.set_trace()
        return self.m(x)
    
class MyModel(tf.keras.Model):
    def __init__(self):
        super().__init__()
#         self.dense1 = tf.keras.layers.Dense(4, activation=tf.nn.relu)
#         self.dense2 = tf.keras.layers.Dense(5, activation=tf.nn.softmax)
        self.m = A()

    def call(self, inputs):
#         x = self.dense1(inputs)
#         if training:
        return self.m(x)
#         return self.dense2(x)

x = np.random.rand(2,3).astype(np.float32)
print(x)
model = MyModel()
print(model(x,training=True))
model.trainable_variables

# %%
# from preprocess import preprocess
# preprocess()

# %%
# paddlepaddle
import paddle.fluid as fluid
from darts_pp.search import Searching
from darts_pp.train import Training
from darts_pp.prediction import Prediction
with fluid.dygraph.guard():
#     s = Searching()
#     s.search()
#     t = Training()
#     t.main_run()
    p = Prediction()
    p.predict()

# %%
# pytorch
from darts_pt.search import Searching
# from darts_pt.train import Training
# from darts_pt.prediction import Prediction
s = Searching()
s.search()
# t = Training()
# t.main_run()
# p = Prediction()
# p.predict()

# %%
import paddle.fluid as fluid
import numpy as np
import pdb
from darts_pp.ops import *
import torch
from darts_pt.utils import accuracy
from paddle.fluid.dygraph.nn import Conv2D, Pool2D, BatchNorm, Linear

def test():
#     pdb.set_trace()
    y_pred = np.random.rand(2,10).astype('float32')
    y = np.random.randint(0,10,(2,))
    print(y_pred,y)
    yp_t = torch.as_tensor(y_pred, dtype=torch.float)
    y_t = torch.as_tensor(y, dtype=torch.long)
    lt = torch.nn.CrossEntropyLoss()(yp_t,y_t)
    print('torch loss: {}'.format(lt))
    print('torch acc: {}'.format(accuracy(yp_t,y_t,topk=(1,5))))
    m = torch.nn.Conv2d(2,2,1)
#     for i in m.parameters():
#         print(i.dtype)
    with fluid.dygraph.guard():
        y_pp = fluid.dygraph.to_variable(y[:,np.newaxis])
        yp_pp = fluid.dygraph.to_variable(y_pred)
        lpp = fluid.layers.reduce_mean(fluid.layers.softmax_with_cross_entropy(yp_pp, y_pp))
#         print('pp loss: {}'.format(lpp.numpy()))
        print('pp acc: {}'.format([fluid.layers.accuracy(yp_pp, y_pp, k=1).numpy(), 
                                  fluid.layers.accuracy(yp_pp, y_pp, k=5).numpy()]))
#         print(sum([lpp,lpp]))
        
#         m = Pool2D(pool_type='avg', global_pooling=True)
#         print(m(y_pred).shape)
#         a = fluid.dygraph.to_variable(value)
        
#         for i in OPS:
#             print(i, OPS[i](2,2,False)(a).shape)
        
#         alpha = fluid.layers.create_parameter([1], 'float32')

#         linear = fluid.Linear(3, 2, dtype="float32")
#         for i in linear.parameters():
#             print(i.dtype)

#         print((list(linear.parameters())))
#         adam = fluid.optimizer.Adam(parameter_list=linear.parameters())
# #         out = linear(a)
#         out = linear(value)
#         print(type(linear))
#         out.backward()
#         adam.minimize(out)
#         linear.clear_gradients()
test()

# %%
import paddle.fluid as fluid
from paddle.fluid.param_attr import ParamAttr
from paddle.fluid.initializer import NormalInitializer, MSRAInitializer, ConstantInitializer

with fluid.dygraph.guard():
    emb = fluid.dygraph.Embedding(
        size=[2, 2],
        param_attr='emb.w',
        is_sparse=False)
    state_dict = emb.state_dict()
    with open('paddle.pkl','wb') as f:
        pickle.dump(state_dict,f)
    print(state_dict)
    fluid.save_dygraph(state_dict, "paddle_dy")  # 会保存为 paddle_dy.pdparams

    adam = fluid.optimizer.Adam(
#         learning_rate=0.001,
        parameter_list = emb.parameters())
    state_dict = adam.state_dict()
    adam._learning_rate=0.2
    print(adam.current_step_lr())
#     fluid.save_dygraph({1:2}, "paddle_dy")  # 会保存为 paddle_dy.pdopt

with fluid.dygraph.guard():
    emb2 = fluid.dygraph.Embedding(
        size=[2, 2],
        param_attr='emb.w',
        is_sparse=False)
    state_dict = emb2.state_dict()
    print(state_dict)
    with open('paddle.pkl','rb') as f:
        sd = pickle.load(f)
#     model_states,_ = fluid.load_dygraph('paddle_dy')
#     print(model_states)
    emb2.set_dict(fluid.load_dygraph('paddle_dy')[0])
#     emb2.set_dict(sd)
    print(emb2.state_dict())
    try:
        fluid.load_dygraph('paddle')
    except RuntimeError:
        pass
import pickle

# print(adam.current_step_lr())

# %%
a = fluid.dygraph.LayerList()
a.append(fluid.dygraph.nn.Linear(1,1))
from paddle.fluid.param_attr import ParamAttr
ParamAttr?

# %%
import paddle.fluid as fluid
from paddle.fluid.dygraph.base import to_variable
import numpy as np
from torch.functional import F
import torch
import tensorflow as tf
with fluid.dygraph.guard():
#     data = np.random.random((3, 1,32, 32)).astype('float32')
    
# #     pool2d = fluid.dygraph.Pool2D(pool_size=2,
# #                   pool_type='max',
# #                   pool_stride=1,
# #                   global_pooling=False)
#     pool2d = fluid.dygraph.Pool2D(pool_type='avg', global_pooling=True)
#     pool2d_res = pool2d(to_variable(data))
#     print(pool2d_res.shape)
    
    x = np.random.rand(2,3)
    print(x)
    tx = torch.as_tensor(x)
    print(F.softmax(tx,dim=0))
    print(F.softmax(tx,dim=-1))
    print(fluid.layers.softmax(to_variable(x)).numpy())
    print(tf.nn.softmax(x))

# %%
v = tf.Variable(np.zeros((2,3)),trainable=True)
v

# %%
from darts_pp.utils import ReduceLROnPlateau
s = ReduceLROnPlateau(1,patience=2)
s.step(10)
print(s.count,s.record)
s.step(9)
print(s.count,s.record)
s.step(10)
print(s.count,s.record)
sd = s.state_dict()
for i in sd:
    sd[i] += 200
s.load_state_dict(sd, full_load=True)
s.state_dict()

# %%
import pickle
# with open('xxx', 'wb') as f:
#     pickle.dump({2:1}, f)
with open('darts_pp/log/best_genotype.pkl', 'rb') as f:
    a = pickle.load(f)
print(a)

# %%
import paddle.fluid.dygraph.nn as nn
from paddle.fluid.dygraph import Dropout
nn?
